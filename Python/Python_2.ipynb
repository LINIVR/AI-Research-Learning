# %% [markdown]
# # Python Practice – Part 2
#
#
# ## Goal
# Learn fundamental Python concepts through hands-on coding practice.
#
# This notebook covers:
# - Dynamic typing
# - Mutable vs immutable data types
# - Local and global variables
# - Functions and return statements
# - List comprehension
# - break, continue, and pass
# - Recursion
# - Lambda functions
# - is vs ==
# - Docstrings

# %% [markdown]
# # 1. Dynamic Typing
#
# ## Question
# Assign an integer value to a variable,
# then reassign a string value to the same variable.
#
# Print the value and datatype at each step.
#
# ## Explanation
# Python is dynamically typed, meaning the same variable
# can store different types of values during runtime.

# %%
# Assign integer value
x = 10

# Display value and datatype
print(x, type(x))

# Reassign string value
x = "Hello Python"

# Display updated value and datatype
print(x, type(x))
# Out:
# 10 <class 'int'>
# Hello Python <class 'str'>

# %% [markdown]
# # 2. Mutable vs Immutable Data Types
#
# ## Question
# Modify a list and attempt to modify a tuple.
#
# ## Explanation
# Lists are mutable because elements can be changed.
# Tuples are immutable and cannot be modified after creation.

# %%
# Create list
my_list = [1, 2, 3]

# Modify first element
my_list[0] = 10

# Display updated list
print(my_list)

# Create tuple
my_tuple = (1, 2, 3)

# Tuples are immutable
# my_tuple[0] = 10

# Display tuple
print(my_tuple)
# Out:
# [10, 2, 3]
# (1, 2, 3)

# %% [markdown]
# # 3. Local and Global Variables
#
# ## Question
# Use a global variable and a local variable inside a function.
#
# ## Explanation
# A global variable can be accessed throughout the program,
# while a local variable exists only inside the function.

# %%
# Global variable
x = 100

# Function definition
def demo():

    # Local variable
    y = 50

    # Display global and local variables
    print(x, y)

# Function call
demo()
# Out:
# 100 50

# %%
x=100
def demo():
  y=50
  print(x,y)

demo()
# Out:
# 100 50

# %% [markdown]
# # 4. Return Statement in a Function
#
# ## Question
# Create a function that takes two numbers
# and returns their sum.
#
# ## Explanation
# The return statement sends the result back
# to the function caller.

# %%
# Function definition
def add(a, b):

    # Return sum
    return a + b

# Store returned value
result = add(5, 3)

# Display result
print(result)
# Out:
# 8

# %% [markdown]
# # 5. List Comprehension
#
# ## Question
# Create a list of squares from 1 to 10.
#
# ## Explanation
# List comprehension provides a compact way
# to create lists in Python.

# %%
# Create list of squares
squares = [x * x for x in range(1, 11)]

# Display list
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# # 6. break, continue, and pass
#
# ## Question
# Demonstrate break, continue, and pass statements.
#
# ## Explanation
# - continue skips current iteration
# - break exits loop
# - pass acts as placeholder

# %%
# Loop from 1 to 10
for i in range(1, 11):

    # Skip iteration when i is 3
    if i == 3:
        continue

    # Exit loop when i is 5
    if i == 5:
        pass

    # Placeholder statement
    if i == 7:
        break

    # Display value
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# # 7. Recursion
#
# ## Question
# Create a recursive function to find factorial of a number.
#
# ## Explanation
# Recursion occurs when a function calls itself.

# %%
# Recursive factorial function
def factorial(n):

    # Base condition
    if n == 0:
        return 1

    # Recursive call
    return n * factorial(n - 1)

# Display factorial
print(factorial(5))
# Out:
# 120

# %% [markdown]
# # 8. Lambda Function
#
# ## Question
# Create a lambda function to calculate square of a number.
#
# ## Explanation
# Lambda functions are small anonymous functions
# written in a single line.

# %%
# Lambda function for square
square = lambda x: x * x

# Display result
print(square(4))
# Out:
# 16

# %% [markdown]
# # 9. is vs ==
#
# ## Question
# Compare two lists using == and is.
#
# ## Explanation
# - == compares values
# - is compares memory locations

# %%
# Create lists
a = [1, 2, 3]
b = [1, 2, 3]

# Compare values
print(a == b)

# Compare memory locations
print(a is b)
# Out:
# True
# False

# %% [markdown]
# # 10. Docstrings
#
# ## Question
# Create a function using a docstring.
#
# ## Explanation
# Docstrings are used to describe the purpose of functions,
# classes, or modules.

# %%
# Function definition
def greet():

    """This function prints a greeting message"""

    print("Hello Python")

# Function call
greet()

# Display docstring
print(greet.__doc__)
# Out:
# Hello Python
# This function prints a greeting message

# %% [markdown]
# #
